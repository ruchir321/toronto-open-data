# %% [markdown]
# # TPL
#
# - Library programs and events feed
# - Library visits
# -

# %%
import os
os.chdir("../")
cwd = os.getcwd()
print(cwd)
# Out:
# /home/ruchirich/Documents/repositories/toronto-open-data/tpl

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

from utils.download_data import download_data
import math

# %%
pd.set_option('display.max_colwidth', 50)

# %%
pd.set_option('display.max_columns', None)

# %%
# Datasets are called "packages". Each package can contain many "resources"
# To retrieve the metadata for this package and its resources, use the package name in this page's URL:
params = { "id": "library-branch-programs-and-events-feed"}
download_file = cwd+"/data/library-branch-programs-and-events-feed.csv"

download_data(params, download_file)

# %%
# df = pd.read_csv(download_file, index_col='Timestamp', parse_dates=True, date_format="ISO8601", usecols=['Timestamp', 'Sales Count', 'Redemption Count'])
df = pd.read_csv(download_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4435 entries, 0 to 4434
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              4435 non-null   int64
#  1   title            4435 non-null   object
#  2   startdate        4435 non-null   object
#  3   enddate          16 non-null     object
#  4   starttime        4419 non-null   object
#  5   endtime          4419 non-null   object
#  6   library          4435 non-null   object
#  7   location         2180 non-null   object
#  8   description      4435 non-null   object
#  9   pagelink         4435 non-null   object
#  10  id               4435 non-null   int64
#  11  rcid             4435 non-null   int64
#  12  eventtype1       4435 non-null   object
#  13  eventtype2       1481 non-null   object
#  14  eventtype3       200 non-null    object
#  15  agegroup1        4435 non-null   object
# ...

# %%
df.head()
# Out:
#    _id                                              title   startdate  \
# 0    1                Basic Tech Help: Senior's E-Connect  2024-12-13
# 1    2                                  English Book Club  2025-01-18
# 2    3                             Creative Writing Group  2025-01-29
# 3    4                                Tea & Entertainment  2025-01-10
# 4    5  Patterns and Puffed Sleeves: Costume Design Th...  2024-10-05
#
#       enddate starttime endtime                     library location  \
# 0  2025-12-31       NaN     NaN                   Cedarbrae      NaN
# 1  2025-12-20       NaN     NaN                   Cedarbrae      NaN
# 2  2025-12-17       NaN     NaN                   Cedarbrae      NaN
# 3  2025-04-25       NaN     NaN  North York Central Library      NaN
# 4  2025-01-26       NaN     NaN   Toronto Reference Library      NaN
#
#                                          description  \
# 0  Do you have a phone, tablet or computer you do...
# ...

# %%
df.location.unique()
# Out:
# array([nan, 'Auditorium (FCCR)', 'Program Room',
#        'Program Room - 2nd Floor', 'Story Room', 'Multipurpose Room',
#        'Learning Centre', 'Meeting Room', 'Meeting Room 1',
#        'Adult Program Room', "Children's Program Room", 'theatre',
#        'Auditorium', 'Youth Hub', 'Community Room',
#        'Digital Innovation Hub', 'Small Meeting Room - 2ndÂ\xa0Floor',
#        'Learning Centre 1', 'Enhanced Learning Centre', 'Room 200',
#        'Elearning Lab', 'Discussion Room', "Founders' Room", 'Room 101',
#        'TD Gallery', 'Program Room - Basement', 'Small Program Room',
#        'Fabrication Studio', 'Basement', 'Program Room - Main Floor',
#        'Room 224', 'Art Gallery',
#        'Digital Innovation Hub - 2ndÂ\xa0Floor', 'Beeton Hall',
#        'Browsery', 'Urban Living Room', 'Bram & Bluma Appel Salon',
#        'Hinton Learning Theatre', 'Room 2/3', 'Room 1', 'meeting room',
#        'Jack Rabinovitch Reading Room', 'Concourse Event Space'],
# ...

# %%
for k, v in df.groupby(['eventtype1', 'eventtype2', 'eventtype3']).groups.items():
    print(k)
    print(v)
    break
# Out:
# ('00-After School', '00-Culture Arts & Entertainment', '00-Hobbies Crafts & Games')
# Index([1216, 1659, 2065, 2460], dtype='int64')

# %%
event_groups = df.groupby(['eventtype1', 'eventtype2', 'eventtype3'])

# %%
group_1 = event_groups.get_group(('00-After School', '00-Culture Arts & Entertainment', '00-Hobbies Crafts & Games'))

# %%
group_1.head()
# Out:
#        _id                                         title   startdate enddate  \
# 1216  1217  WAITLIST - Brush & Beyond Visual Arts Series  2025-02-04     NaN
# 1659  1660  WAITLIST - Brush & Beyond Visual Arts Series  2025-02-11     NaN
# 2065  2066  WAITLIST - Brush & Beyond Visual Arts Series  2025-02-18     NaN
# 2460  2461  WAITLIST - Brush & Beyond Visual Arts Series  2025-02-25     NaN
#
#      starttime  endtime    library      location  \
# 1216   5:00 PM  6:30 PM  Hillcrest  Program Room
# 1659   5:00 PM  6:30 PM  Hillcrest  Program Room
# 2065   5:00 PM  6:30 PM  Hillcrest  Program Room
# 2460   5:00 PM  6:30 PM  Hillcrest  Program Room
#
#                                             description  \
# 1216  Brush & Beyond has partnered with Hillcrest Li...
# 1659  Brush & Beyond has partnered with Hillcrest Li...
# 2065  Brush & Beyond has partnered with Hillcrest Li...
# 2460  Brush & Beyond has partnered with Hillcrest Li...
#
# ...
